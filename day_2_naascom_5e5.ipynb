# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

# -------------------------------------------------------
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate sensor data
raw_sensor_data = []

base_time = datetime.datetime(2026, 1, 1, 12, 0, 0)

for i in range(100):
    timestamp = base_time + datetime.timedelta(minutes=i * 5 + random.randint(0, 4))
    timestamp_str = timestamp.strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append(
        (timestamp_str, device_id, device_type, location, value)
    )

print(raw_sensor_data)

# -------------------------------------------------------
# 1.2 Temperature readings

temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

print(temperature_readings)

# -------------------------------------------------------
# 1.3 Unique locations

unique_locations = {reading[3] for reading in raw_sensor_data}

print(unique_locations)

# -------------------------------------------------------
# 1.4 Device statistics

device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    device_stats[device] = (
        min(current_min, value),
        max(current_max, value)
    )

print(device_stats)

# -------------------------------------------------------
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)
print(sliced_readings_2)

# -------------------------------------------------------
# 1.5.2

substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)

# -------------------------------------------------------
# 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)

# -------------------------------------------------------
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


print(get_readings_by_location(raw_sensor_data, "Lab1"))

# -------------------------------------------------------
# 2.2

def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    return total / len(temp_data_list)


print(calculate_average_temperature(temperature_readings))

# -------------------------------------------------------
# 2.3

def generate_report_line(reading_dict):

    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

if temperature_readings:
    print(generate_report_line(temperature_readings[0]))

# -------------------------------------------------------
print("\n--- Task 3: Core Library Usage ---")

# 3.1

reports_dir = "sensor_reports"

os.makedirs(reports_dir, exist_ok=True)

print(f"Directory '{reports_dir}' is ready.")

# -------------------------------------------------------
# 3.2

first = datetime.datetime.strptime(
    raw_sensor_data[0][0],
    "%Y-%m-%d %H:%M:%S"
)

last = datetime.datetime.strptime(
    raw_sensor_data[-1][0],
    "%Y-%m-%d %H:%M:%S"
)

duration = last - first

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")

# -------------------------------------------------------
# 3.3

random_values = [random.randint(100, 200) for _ in range(5)]

print(random_values)

# -------------------------------------------------------
print("\n--- Task 4: File I/O ---")

# 4.1

report_filename = os.path.join(
    reports_dir,
    "temperature_report.txt"
)

with open(report_filename, "w") as file:

    for reading in temperature_readings:
        file.write(generate_report_line(reading) + "\n")

print("Temperature report written successfully.")

# -------------------------------------------------------
# 4.2

with open(report_filename, "r") as file:
    read_report_lines = file.readlines()

print("First 3 lines of the report:")

for line in read_report_lines[:3]:
    print(line.strip())

# -------------------------------------------------------
print("\n--- Exercise Complete! ---")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# [('2026-01-01 12:04:00', 'DEV001', 'Pressure_Sensor', 'OfficeB', 1019.53), ('2026-01-01 12:06:00', 'DEV002', 'Temperature_Sensor', 'OfficeB', 20.12), ('2026-01-01 12:12:00', 'DEV003', 'Humidity_Sensor', 'OfficeB', 75.15), ('2026-01-01 12:16:00', 'DEV004', 'Humidity_Sensor', 'Warehouse', 53.59), ('2026-01-01 12:24:00', 'DEV005', 'Temperature_Sensor', 'Lab1', 25.42), ('2026-01-01 12:27:00', 'DEV006', 'Temperature_Sensor', 'OfficeA', 28.13), ('2026-01-01 12:34:00', 'DEV007', 'Light_Sensor', 'Lab2', 275.16), ('2026-01-01 12:35:00', 'DEV008', 'Pressure_Sensor', 'Lab2', 982.75), ('2026-01-01 12:44:00', 'DEV009', 'Pressure_Sensor', 'OfficeA', 1017.52), ('2026-01-01 12:49:00', 'DEV010', 'Humidity_Sensor', 'Lab2', 34.05), ('2026-01-01 12:51:00', 'DEV011', 'Pressure_Sensor', 'Lab2', 989.62), ('2026-01-01 12:55:00', 'DEV012', 'Temperature_Sensor', 'Lab1', 22.37), ('2026-01-01 13:02:00', 'DEV013', 'Humidity_Sensor', 'Offic
# [2026-01-01 12:06:00] Device DEV002 at OfficeB: 20.12°C
#
# --- Task 3: Core Library Usage ---
# Directory 'sensor_reports' is ready.
# Duration: 0 days, 8 hours, 12 minutes
# [144, 145, 148, 116, 106]
#
# --- Task 4: File I/O ---
# Temperature report written successfully.
# First 3 lines of the report:
# [2026-01-01 12:06:00] Device DEV002 at OfficeB: 20.12°C
# [2026-01-01 12:24:00] Device DEV005 at Lab1: 25.42°C
# [2026-01-01 12:27:00] Device DEV006 at OfficeA: 28.13°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.

# %%
import datetime
import random
raw_data=[]
base_time=datetime.datetime(2026,1,1,12,0,0)
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
       }
for i in range(100):
  time=base_time+datetime.timedelta(minutes=i*5+random.randint(0,4))
  time_result=time.strftime("%Y-%m-%d %H:%M:%S")
  device_id=f'DEV{i+1:03d}'
  device_type=random.choice(DEVICE_TYPES)
  location=random.choice(LOCATIONS)
  min_1,max_1=READING_RANGES[device_type]
  values=round(random.uniform(min_1 ,max_1),2)
  raw_data.append((time_result,device_id,device_type,location,values))
print(raw_data)

temp_data=[]
for i in raw_data:
  if i[2]=='Temperature_Sensor':
    temp_data.append({'time_result':i[0],'device_id':i[1],'location':i[3],'values':i[4]})
print(temp_data)

unique_location=set()
for item in raw_data:
  unique_location.add(item[3])
unique=tuple(unique_location)
print(unique)

device_stats=[]
for item in raw_data:
  device_stats.append({"key":item[2],"value":item[4]})
print(device_stats)

sliced_readings_1=raw_data[10:21]
sliced_readings_2=raw_data[::5]
print(sliced_readings_1)
print(sliced_readings_2)

sample_string="PythonProgrammingIsFun"
sub_string_1=sample_string[6:17]
sub_string_2=sample_string[5::-1]
print(sub_string_1)
print(sub_string_2)


fifth_reading=raw_data[4][2]
suffix=fifth_reading[-6:]
print(fifth_reading)
print(suffix)


def get_readings_by_location(readings_list,target_location):
  temp_data=[]
  for i in readings_list:
    if i[2]==target_location:
      temp_data.append(i[4])
  print(temp_data)
get_readings_by_location(raw_data,'Temperature_Sensor')


def generate_report_line(reading_dict):
  reading=random.choice(raw_data)
  report=f"[{time_result}] Device {device_id} at {location}: {values}°C"
  print(report)
generate_report_line(raw_data)
# Out:
 23.01}, {'time_result': '2026-01-01 16:49:00', 'device_id': 'DEV058', 'location': 'Lab1', 'values': 24.19}, {'time_result': '2026-01-01 16:53:00', 'device_id': 'DEV059', 'location': 'OfficeA', 'values': 25.87}, {'time_result': '2026-01-01 17:05:00', 'device_id': 'DEV062', 'location': 'Lab1', 'values': 22.9}, {'time_result': '2026-01-01 17:43:00', 'device_id': 'DEV069', 'location': 'OfficeB', 'values': 25.24}, {'time_result': '2026-01-01 17:58:00', 'device_id': 'DEV072', 'location': 'Lab1', 'values': 19.61}, {'time_result': '2026-01-01 19:03:00', 'device_id': 'DEV085', 'location': 'Lab1', 'values': 25.58}, {'time_result': '2026-01-01 19:15:00', 'device_id': 'DEV088', 'location': 'Warehouse', 'values': 24.34}, {'time_result': '2026-01-01 19:26:00', 'device_id': 'DEV090', 'location': 'OfficeB', 'values': 22.62}, {'time_result': '2026-01-01 19:33:00', 'device_id': 'DEV091', 'location': 'OfficeA', 'values': 24.55}, {'time_result': '2026-01-01 20:02:00', 'device_id': 'DEV097', 'location': 'OfficeA', 'values': 24.13}, {'time_result': '2026-01-01 20:05:00', 'device_id': 'DEV098', 'location': 'Warehouse', 'values': 18.49}]
# ('Warehouse', 'OfficeB', 'Lab1', 'Lab2', 'OfficeA')
# [{'key': 'Pressure_Sensor', 'value': 1021.68}, {'key': 'Light_Sensor', 'value': 808.29}, {'key': 'Temperature_Sensor', 'value': 24.0}, {'key': 'Temperature_Sensor', 'value': 23.54}, {'key': 'Light_Sensor', 'value': 358.5}, {'key': 'Light_Sensor', 'value': 893.51}, {'key': 'Light_Sensor', 'value': 695.1}, {'key': 'Light_Sensor', 'value': 918.74}, {'key': 'Humidity_Sensor', 'value': 73.75}, {'key': 'Light_Sensor', 'value': 992.45}, {'key': 'Humidity_Sensor', 'value': 42.09}, {'key': 'Humidity_Sensor', 'value': 50.56}, {'key': 'Light_Sensor', 'value': 685.9}, {'key': 'Light_Sensor', 'value': 295.72}, {'key': 'Temperature_Sensor', 'value': 22.52}, {'key': 'Light_Sensor', 'value': 106.7}, {'key': 'Temperature_Sensor', 'value': 28.11}, {'key': 'Pressure_Sensor', 'value': 994.81}, {'key': 'Temperature_Sensor', 'value': 22.88}, {'key': 'Pressure_Sensor', 'value': 981.35}, {'key': 'Pressure_Sensor', 'value': 1021.17}, {'key': 'Temperature_Sensor', 'value': 20.32}, {'key': 'Light_Sensor', 'value': 597.48}, {'key': 'Pressure_Sensor', 'value': 1004.79}, {'key': 'Temperature_Sensor', 'value': 26.09}, {'key': 'Pressure_Sensor', 'value': 1002.82}, {'key': 'Humidity_Sensor', 'value': 36.85}, {'key': 'Temperature_Sensor', 'value': 23.32}, {'key': 'Humidity_Sensor', 'value': 35.55}, {'key': 'Pressure_Sensor', 'value': 1004.05}, {'key': 'Humidity_Sensor', 'value': 60.36}, {'key': 'Light_Sensor', 'value': 992.05}, {'key': 'Pressure_Sensor', 'value': 981.04}, {'key': 'Light_Sensor', 'value': 752.02}, {'key': 'Humidity_Sensor', 'value': 61.68}, {'key': 'Light_Sensor', 'value': 375.19}, {'key': 'Light_Sensor', 'value': 669.97}, {'key': 'Pressure_Sensor', 'value': 988.25}, {'key': 'Temperature_Sensor', 'value': 19.94}, {'key': 'Light_Sensor', 'value': 151.17}, {'key': 'Humidity_Sensor', 'value': 65.69}, {'key': 'Humidity_Sensor', 'value': 76.74}, {'key': 'Humidity_Sensor', 'value': 47.91}, {'key': 'Humidity_Sensor', 'value': 54.33}, {'key': 'Light_Sensor', 'value': 424.14}, {'key': 'Humidity_Sensor', 'value': 74.52}, {'key': 'Light_Sensor', 'value': 376.94}, {'key': 'Light_Sensor', 'value': 382.41}, {'key': 'Pressure_Sensor', 'value': 999.1}, {'key': 'Light_Sensor', 'value': 542.82}, {'key': 'Temperature_Sensor', 'value': 23.78}, {'key': 'Temperature_Sensor', 'value': 25.34}, {'key': 'Light_Sensor', 'value': 808.0}, {'key': 'Light_Sensor', 'value': 960.21}, {'key': 'Light_Sensor', 'value': 683.11}, {'key': 'Temperature_Sensor', 'value': 23.01}, {'key': 'Light_Sensor', 'value': 714.2}, {'key': 'Temperature_Sensor', 'value': 24.19}, {'key': 'Temperature_Sensor', 'value': 25.87}, {'key': 'Humidity_Sensor', 'value': 69.44}, {'key': 'Pressure_Sensor', 'value': 987.31}, {'key': 'Temperature_Sensor', 'value': 22.9}, {'key': 'Light_Sensor', 'value': 814.51}, {'key': 'Humidity_Sensor', 'value': 39.8}, {'key': 'Light_Sensor', 'value': 839.18}, {'key': 'Humidity_Sensor', 'value': 75.43}, {'key': 'Humidity_Sensor', 'value': 39.56}, {'key': 'Pressure_Sensor', 'value': 1023.66}, {'key': 'Temperature_Sensor', 'value': 25.24}, {'key': 'Light_Sensor', 'value': 835.1}, {'key': 'Light_Sensor', 'value': 629.59}, {'key': 'Temperature_Sensor', 'value': 19.61}, {'key': 'Light_Sensor', 'value': 239.53}, {'key': 'Humidity_Sensor', 'value': 48.92}, {'key': 'Light_Sensor', 'value': 833.02}, {'key': 'Light_Sensor', 'value': 594.36}, {'key': 'Pressure_Sensor', 'value': 987.73}, {'key': 'Humidity_Sensor', 'value': 67.47}, {'key': 'Pressure_Sensor', 'value': 990.01}, {'key': 'Humidity_Sensor', 'value': 48.37}, {'key': 'Light_Sensor', 'value': 238.26}, {'key': 'Humidity_Sensor', 'value': 56.77}, {'key': 'Humidity_Sensor', 'value': 45.69}, {'key': 'Light_Sensor', 'value': 141.99}, {'key': 'Temperature_Sensor', 'value': 25.58}, {'key': 'Pressure_Sensor', 'value': 984.44}, {'key': 'Humidity_Sensor', 'value': 70.5}, {'key': 'Temperature_Sensor', 'value': 24.34}, {'key': 'Humidity_Sensor', 'value': 79.26}, {'key': 'Temperature_Sensor', 'value': 22.62}, {'key': 'Temperature_Sensor', 'val ...
